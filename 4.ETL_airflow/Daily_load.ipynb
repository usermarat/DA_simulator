# %%
import pandahouse as ph

# %%
connection_test = {'host': 'https://clickhouse.lab.karpov.courses',
                  'user':'student-rw',
                  'password':'656e2b0c9c',
                   'database':'test',
                  }

# %%
df = ph.read_clickhouse('select * from test.task6_ahmadeev', connection=connection_test)

# %%
df.head(10)
# Out:
#   event_date dimension dimension_value   views  likes  messages_received  \
# 0 2023-07-05        os         Android  441659  95235               8256
# 1 2023-07-05        os             iOS  240797  51863               4644
# 2 2023-07-05    gender               0  304311  65689               6314
# 3 2023-07-05    gender               1  378145  81409               6586
# 4 2023-07-05       age              14    9977   2144                548
# 5 2023-07-05       age              15   22024   4774                148
# 6 2023-07-05       age              16   27562   5952                281
# 7 2023-07-05       age              17   33405   7341                413
# 8 2023-07-05       age              18   36653   8018                744
# 9 2023-07-05       age              19   40576   8692                857
#
#    messages_sent  users_received  users_sent
# 0           8409            6187        6035
# 1           4491            3256        3408
# ...

# %%
df.groupby(['event_date', 'dimension']).dimension_value.value_counts()
# Out:
# event_date  dimension  dimension_value
# 2023-07-05  age        14                 1
#                        15                 1
#                        16                 1
#                        17                 1
#                        18                 1
#                                          ..
# 2023-08-12  age        73                 1
#             gender     0                  1
#                        1                  1
#             os         Android            1
#                        iOS                1
# Name: dimension_value, Length: 2714, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2714 entries, 0 to 2713
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   event_date         2714 non-null   datetime64[ns]
#  1   dimension          2714 non-null   object
#  2   dimension_value    2714 non-null   object
#  3   views              2714 non-null   int64
#  4   likes              2714 non-null   int64
#  5   messages_received  2714 non-null   int64
#  6   messages_sent      2714 non-null   int64
#  7   users_received     2714 non-null   int64
#  8   users_sent         2714 non-null   int64
# dtypes: datetime64[ns](1), int64(6), object(2)
# memory usage: 191.0+ KB

# %%
df.dimension.value_counts()
# Out:
# age       2558
# os          78
# gender      78
# Name: dimension, dtype: int64

# %%
df.event_date.nunique()
# Out:
# 39

# %%
df.query('dimension == "os"')
# Out:
#      event_date dimension dimension_value   views   likes  messages_received  \
# 0    2023-07-05        os         Android  441659   95235               8256
# 1    2023-07-05        os             iOS  240797   51863               4644
# 68   2023-07-06        os         Android  427730   93684               8583
# 69   2023-07-06        os             iOS  235106   51757               4317
# 138  2023-07-07        os         Android  428988   93377              22293
# ...         ...       ...             ...     ...     ...                ...
# 2517 2023-08-10        os             iOS  264364   56769               4568
# 2585 2023-08-11        os         Android  475011  100430               7723
# 2586 2023-08-11        os             iOS  257843   54131               5494
# 2655 2023-08-12        os         Android       0       0               8916
# 2656 2023-08-12        os             iOS       0       0               3666
#
# ...

# %%
df.to_csv('task6_ahmadeev.csv')

# %%
df = ph.read_clickhouse('select * from test.task6_ahmadeev', connection=connection_test)

# %%
df
# Out:
#     event_date dimension dimension_value   views  likes  messages_received  \
# 0   2023-07-05        os         Android  441659  95235               8256
# 1   2023-07-05        os             iOS  240797  51863               4644
# 2   2023-07-05    gender               0  304311  65689               6314
# 3   2023-07-05    gender               1  378145  81409               6586
# 4   2023-07-05       age              14    9977   2144                548
# ..         ...       ...             ...     ...    ...                ...
# 133 2023-07-06       age              75      12      4                  0
# 134 2023-07-06       age              76      17      3                  0
# 135 2023-07-06       age              77      73     17                  0
# 136 2023-07-06       age              79      33      8                  0
# 137 2023-07-06       age              82      29      5                  0
#
#      messages_sent  users_received  users_sent
# ...

# %%
df.dimension.value_counts()
# Out:
# dimension
# age       130
# os          4
# gender      4
# Name: count, dtype: int64

# %%
df.query('dimension == "gender"')
# Out:
#    event_date dimension dimension_value   views  likes  messages_received  \
# 2  2023-07-05    gender               0  304311  65689               6314
# 3  2023-07-05    gender               1  378145  81409               6586
# 70 2023-07-06    gender               0  299028  65952               6288
# 71 2023-07-06    gender               1  363808  79489               6612
#
#     messages_sent  users_received  users_sent
# 2            5828            4416        4339
# 3            7072            5027        5104
# 70           5983            4908        4746
# 71           6917            5398        5560

# %%
df = ph.read_clickhouse('select * from test.task6_ahmadeev', connection=connection_test)

# %%
df
# Out:
#     event_date dimension dimension_value   views  likes  messages_received  \
# 0   2023-07-06        os         Android  427730  93684               8583
# 1   2023-07-06        os             iOS  235106  51757               4317
# 2   2023-07-06    gender               0  299028  65952               6288
# 3   2023-07-06    gender               1  363808  79489               6612
# 4   2023-07-06       age              14    9245   2018                118
# ..         ...       ...             ...     ...    ...                ...
# 203 2023-07-07       age              76      22      4                  0
# 204 2023-07-07       age              78       0      0                  0
# 205 2023-07-07       age              79      32      9                  0
# 206 2023-07-07       age              82      11      3                  0
# 207 2023-07-07       age              87      39      4                  0
#
#      messages_sent  users_received  users_sent
# ...

# %%
df.dimension.value_counts()
# Out:
# dimension
# age       196
# os          6
# gender      6
# Name: count, dtype: int64

# %%
df.query('dimension == "gender"')
# Out:
#     event_date dimension dimension_value   views  likes  messages_received  \
# 2   2023-07-06    gender               0  299028  65952               6288
# 3   2023-07-06    gender               1  363808  79489               6612
# 72  2023-07-05    gender               0  304311  65689               6314
# 73  2023-07-05    gender               1  378145  81409               6586
# 140 2023-07-07    gender               0  297785  64653              15085
# 141 2023-07-07    gender               1  363029  79029              17174
#
#      messages_sent  users_received  users_sent
# 2             5983            4908        4746
# 3             6917            5398        5560
# 72            5828            4416        4339
# 73            7072            5027        5104
# 140          14566           11126       10927
# 141          17693           13117       13316

# %%
df = ph.read_clickhouse('select * from test.task6_ahmadeev', connection=connection_test)

# %%
df
# Out:
#     event_date dimension dimension_value   views  likes  messages_received  \
# 0   2023-07-10        os         Android  309951  62952               8125
# 1   2023-07-10        os             iOS  165042  33252               4776
# 2   2023-07-10    gender               0  214688  43612               6020
# 3   2023-07-10    gender               1  260305  52592               6881
# 4   2023-07-10       age              14    7123   1508                 77
# ..         ...       ...             ...     ...    ...                ...
# 412 2023-07-09       age              75      22      2                  0
# 413 2023-07-09       age              76      30      7                  0
# 414 2023-07-09       age              79      23      8                  0
# 415 2023-07-09       age              80      20      6                  0
# 416 2023-07-09       age              92       6      2                  0
#
#      messages_sent  users_received  users_sent
# ...

# %%
df.dimension.value_counts()
# Out:
# dimension
# age       393
# os         12
# gender     12
# Name: count, dtype: int64

# %%
df.query('dimension == "gender"')
# Out:
#     event_date dimension dimension_value   views  likes  messages_received  \
# 2   2023-07-10    gender               0  214688  43612               6020
# 3   2023-07-10    gender               1  260305  52592               6881
# 72  2023-07-05    gender               0  304311  65689               6314
# 73  2023-07-05    gender               1  378145  81409               6586
# 140 2023-07-06    gender               0  299028  65952               6288
# 141 2023-07-06    gender               1  363808  79489               6612
# 210 2023-07-07    gender               0  297785  64653              15085
# 211 2023-07-07    gender               1  363029  79029              17174
# 280 2023-07-08    gender               0  263320  53719               5808
# 281 2023-07-08    gender               1  326434  66620               7071
# 350 2023-07-09    gender               0  211235  41421               5532
# ...

# %%
df = ph.read_clickhouse('select * from test.task6_ahmadeev', connection=connection_test)

# %%
df.dimension.value_counts()
# Out:
# age       459
# os         14
# gender     14
# Name: dimension, dtype: int64

# %%
def get_bot(photo, message, chat=None):
    chat_id = chat or 377590876
    my_token = '6325254212:AAHJN2P5vlxyzP_qCk8xMv1DYeRAERk_vko'
    bot = telegram.Bot(token=my_token)
    return bot

# %%
if 'sdf':
    print('123')
# Out:
# 123
